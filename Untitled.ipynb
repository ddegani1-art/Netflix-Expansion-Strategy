# %%
cd /anaconda_projects/949be709-adc0-4e93-b150-b4c1797b3fb9
# Out:
# [Errno 2] No such file or directory: '/anaconda_projects/949be709-adc0-4e93-b150-b4c1797b3fb9'
# /Users/danielledegani/Desktop

# %%
# !git init
# Out:
# Initialized empty Git repository in /Users/danielledegani/Desktop/.git/
